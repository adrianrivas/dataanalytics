# %%
# %load_ext bigdata

# %%
# !head data.tsv
# Out:
# E	{(b),(g),(f)}	[jjj#3,bbb#0,ddd#9,ggg#8,hhh#2]
# A	{(a),(f),(c)}	[ccc#2,ddd#0,aaa#3,hhh#9]
# B	{(f),(e),(a),(c)}	[ddd#2,ggg#5,ccc#6,jjj#1]
# A	{(a),(b)}	[hhh#9,iii#5,eee#7,bbb#1]
# C	{(f),(g),(d),(a)}	[iii#6,ddd#5,eee#4,jjj#3]
# A	{(c),(d)}	[bbb#2,hhh#0,ccc#4,fff#1,aaa#7]
# A	{(g),(d),(a)}	[aaa#5,fff#8,ddd#2,iii#0,jjj#7,ccc#1]
# B	{(b),(a)}	[fff#3,hhh#1,ddd#2]
# E	{(d),(e),(a),(f)}	[eee#4,ccc#5,iii#9,fff#7,ggg#6,bbb#0]
# B	{(d),(b),(g),(f)}	[bbb#7,jjj#9,fff#5,iii#4,ggg#2,eee#3]

# %%
# !hadoop fs -ls
# !hadoop fs -rm -r data.tsv
# !hadoop fs -ls
# Out:
# Found 5 items
# drwxr-xr-x   - root root        512 2021-05-05 22:06 .ipynb_checkpoints
# -rw-r--r--   1 root root       1780 2021-05-18 15:07 data.tsv
# -rwxrwxrwx   1 root root       1313 2021-04-21 18:42 grader.py
# -rwxrwxrwx   1 root root        848 2021-05-18 15:06 question.pig
# -rw-r--r--   1 root root      10028 2021-05-18 15:08 script.ipynb
# Deleted data.tsv
# Found 4 items
# drwxr-xr-x   - root root        512 2021-05-05 22:06 .ipynb_checkpoints
# -rwxrwxrwx   1 root root       1313 2021-04-21 18:42 grader.py
# -rwxrwxrwx   1 root root        848 2021-05-18 15:06 question.pig
# -rw-r--r--   1 root root      10028 2021-05-18 15:08 script.ipynb

# %%
# !hadoop fs -ls
# Out:
# Found 5 items
# drwxr-xr-x   - root root        512 2021-05-05 22:06 .ipynb_checkpoints
# -rw-r--r--   1 root root       1780 2021-05-18 15:10 data.tsv
# -rwxrwxrwx   1 root root       1313 2021-04-21 18:42 grader.py
# -rwxrwxrwx   1 root root        848 2021-05-18 15:06 question.pig
# -rw-r--r--   1 root root      17150 2021-05-18 15:10 script.ipynb

# %%
# !pig -execute 'run question.pig'
# Out:
# 2021-05-18 16:09:03,748 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2021-05-18 16:09:04,294 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - io.bytes.per.checksum is deprecated. Instead, use dfs.bytes-per-checksum
# Deleted output
# 2021-05-18 16:09:05,389 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.textoutputformat.separator is deprecated. Instead, use mapreduce.output.textoutputformat.separator
# 2021-05-18 16:09:05,860 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - session.id is deprecated. Instead, use dfs.metrics.session-id
# 2021-05-18 16:09:05,861 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Initializing JVM Metrics with processName=JobTracker, sessionId=
# ...

# %%
# !cat output/*
# Out:
# a	22
# b	12
# c	17
# d	13
# e	15
# f	25
# g	9

# %%
# !python3 grader.py
# Out:
# 2021-05-18 16:10:52,384 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2021-05-18 16:10:53,092 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - io.bytes.per.checksum is deprecated. Instead, use dfs.bytes-per-checksum
# 2021-05-18 16:10:54,206 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.textoutputformat.separator is deprecated. Instead, use mapreduce.output.textoutputformat.separator
# 2021-05-18 16:10:54,619 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - session.id is deprecated. Instead, use dfs.metrics.session-id
# 2021-05-18 16:10:54,620 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Initializing JVM Metrics with processName=JobTracker, sessionId=
# ...
